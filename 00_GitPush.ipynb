# %%
# %%bash
#
# ### Riaggiorna i permessi per permettere il push
# chmod 700 ~/.ssh
# chmod 600 ~/.ssh/id_ed25519
#
# ### commit e push
# cd ~/tesi_graphrag
# git add .
# #git commit -m "Autosave rapido da notebook"
# #git commit -m "CUSTOM MSG"
# git commit -m "Pre istanziazione e test classi tagging ma setup fatto, runnare 04_04 a 04_06T"
# git push
# Out:
# [addTagReranking fcdbe50] Pre istanziazione e test classi tagging ma setup fatto, runnare 04_04 a 04_06T
#  12 files changed, 1690 insertions(+), 25 deletions(-)
# _FrontendBackup.ipynb => 04_01B_FrontendBackup.ipynb} (100%)
# 1_CreateAndAlter.ipynb => 04_01_BasicsCreateAndAlter.ipynb} (100%)
# tagReranking/04_04B_SidecarBackup.ipynb
# RerankerCrAndAlt.ipynbtebooks/04_tagReranking/04_04_Assigner
#  create mode 100644 notebooks/04_tagReranking/04_05T_PretagTester.ipynb
# te mode 100644 notebooks/04_tagReranking/04_06T_RerankerTest.ipynb
# To github.com:Gorky1724/TesiGraphRAG----JupyterHub-UniNuvola.git
# g -> addTagReranking addTagRerankin
