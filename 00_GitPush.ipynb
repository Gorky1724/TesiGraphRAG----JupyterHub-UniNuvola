# %%
# %%bash
#
# ### Riaggiorna i permessi per permettere il push
# chmod 700 ~/.ssh
# chmod 600 ~/.ssh/id_ed25519
#
# ### commit e push
# cd ~/tesi_graphrag
# git add .
# #git commit -m "Autosave rapido da notebook"
# #git commit -m "CUSTOM MSG"
# git commit -m "Implementata struttura di base. Da continuare con test e a raffinare la struttura"
# git push
# Out:
# [main a5eadfa] Aggiunti panning e zooming alla visualizzazione
# 9 deletions(-)ed, 49 insertions(+), 2
# To github.com:Gorky1724/TesiGraphRAG----JupyterHub-UniNuvola.git
#    cc214e9..a5eadfa  main -> main
