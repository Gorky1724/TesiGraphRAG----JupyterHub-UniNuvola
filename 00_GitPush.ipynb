# %%
# %%bash
#
# ### Riaggiorna i permessi per permettere il push
# chmod 700 ~/.ssh
# chmod 600 ~/.ssh/id_ed25519
#
# ### commit e push
# cd ~/tesi_graphrag
# git add .
# #git commit -m "Autosave rapido da notebook"
# #git commit -m "CUSTOM MSG"
# git commit -m "Lavoro su Tagging in attesa di chiarificazione su come operare per la Distanza"
# git push
# Out:
# [addTagReranking b278a79] Lavoro su Tagging in attesa di chiarificazione su come operare per la Distanza
#  7 files changed, 5 insertions(+), 5 deletions(-)
# adDataSet.ipynb => 02_01_DownloadDataSet.ipynb} (100%)
# DataSet.ipynb => 02_02_IngestDataSet.ipynb} (100%)
# ies.ipynb => 02_03_CreateQueries.ipynb} (100%)uer
#  02_04T_Test.ipynb} (100%)gDataSet/{04T_Test.ipynb =>
# > 03_visualizationAndSidecar/02_01_bashCreationCommands.ipynb} (100%)nb =
# nagerAndAux/02T_Test.ipynb => 03_visualizationAndSidecar/02_02T_Test.ipynb} (94%)
# To github.com:Gorky1724/TesiGraphRAG----JupyterHub-UniNuvola.git
# g -> addTagReranking addTagRerankin
