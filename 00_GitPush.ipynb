# %%
# %%bash
#
# ### Riaggiorna i permessi per permettere il push
# chmod 700 ~/.ssh
# chmod 600 ~/.ssh/id_ed25519
#
# ### commit e push
# cd ~/tesi_graphrag
# git add .
# #git commit -m "Autosave rapido da notebook"
# #git commit -m "CUSTOM MSG"
# git commit -m "Lavoro su armstrong e raffinamento assegnazione tag"
# git push
# Out:
# [addTagReranking f1495b8] Lavoro su armstrong e raffinamento assegnazione tag
# 0 insertions(+), 159 deletions(-)
# n.ipynb mode 100644 notebooks/04V_Testing/04V_01_ArmstrongIngestio
#  create mode 100644 notebooks/04V_Testing/04V_02_PreTagging.ipynb
# oks/04V_Testing/04v_03_Reranking.ipynb
# To github.com:Gorky1724/TesiGraphRAG----JupyterHub-UniNuvola.git
# g -> addTagReranking addTagRerankin
