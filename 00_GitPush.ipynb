# %%
# %%bash
#
# ### Riaggiorna i permessi per permettere il push
# chmod 700 ~/.ssh
# chmod 600 ~/.ssh/id_ed25519
#
# ### commit e push
# cd ~/tesi_graphrag
# git add .
# #git commit -m "Autosave rapido da notebook"
# #git commit -m "CUSTOM MSG"
# git commit -m "Implementati gestione file sidecar (via JSON) e Drag and Drop nel grafo"
# git push
# Out:
# [main 8b6a84e] Implementati DataSet e struttura per implementarne di nuovi
# sertions(+), 123 deletions(-)
#  create mode 100644 00_GitPush.ipynb
# startEnv.ipynb (93%)pynb => 00_Re
#  rename CheckOnline.ipynb => 01_CheckOnline.ipynb (92%)
# Push.ipynbde 100644 Git
#  rename Config&Test.ipynb => notebooks/01_configEnv/Config&Test.ipynb (100%)
#  100644 notebooks/02_configDataSet/01_DownloadDataSet.ipynb
# ataSet/02_IngestDataSet.ipynb/02_configD
#  create mode 100644 notebooks/02_configDataSet/03_CreateQueries.ipynb
#  create mode 100644 notebooks/02_configDataSet/04T_Test.ipynb
# To github.com:Gorky1724/TesiGraphRAG----JupyterHub-UniNuvola.git
#    90a96ec..8b6a84e  main -> main
