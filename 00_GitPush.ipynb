# %%
# %%bash
#
# ### Riaggiorna i permessi per permettere il push
# chmod 700 ~/.ssh
# chmod 600 ~/.ssh/id_ed25519
#
# ### commit e push
# cd ~/tesi_graphrag
# git add .
# #git commit -m "Autosave rapido da notebook"
# #git commit -m "CUSTOM MSG"
# git commit -m "Inizio lavori per aggiungere le features con distanza"
# git push
# Out:
# [addDistanceToPipeline 5e51248] Inizio lavori per aggiungere le features con distanza
# ed, 61 insertions(+), 10 deletions(-)
# eateAndAlter.ipynb4 notebooks/05_Distance2ndRetrieval/05_01_Cr
# To github.com:Gorky1724/TesiGraphRAG----JupyterHub-UniNuvola.git
# ipeline -> addDistanceToPipelineToP
