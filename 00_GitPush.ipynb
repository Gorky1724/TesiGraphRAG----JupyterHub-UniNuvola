# %%
# %%bash
#
# ### Riaggiorna i permessi per permettere il push
# chmod 700 ~/.ssh
# chmod 600 ~/.ssh/id_ed25519
#
# ### commit e push
# cd ~/tesi_graphrag
# git add .
# #git commit -m "Autosave rapido da notebook"
# #git commit -m "CUSTOM MSG"
# git commit -m "Implementata struttura di base. Da continuare con test e a raffinare la struttura"
# git push
# Out:
# [distanceReranking 2832089] Implementata struttura di base. Da continuare con test e a raffinare la struttura
#  16 files changed, 937 insertions(+), 79 deletions(-)
# 01_DownloadDataSet.ipynb => 02_01_DownloadDataSet.ipynb} (100%)
# 02_IngestDataSet.ipynb => 02_02_IngestDataSet.ipynb} (100%)
# reateQueries.ipynb => 02_03_CreateQueries.ipynb} (100%)
# .ipynb => 02_04T_Test.ipynb} (100%){04T_Test
# .ipynb => 03_01_bashCreationCommands.ipynb} (100%)eationCommands
# .ipynb => 03_02T_Test.ipynb} (100%)ecar/{02T_Test
# mplementation.ipynb notebooks/04_distanceReranking/04_01_SystemI
#  create mode 100644 notebooks/04_distanceReranking/04_02T_TestPipeline.ipynb
# lete mode 100644 notebooks/04_rerankingDistance/01_rerankingImpl.ipynb
# nce_reranker.py0644 src/dista
# To github.com:Gorky1724/TesiGraphRAG----JupyterHub-UniNuvola.git
# ing -> distanceRerankingtanceRerank
