# %%
# %%bash
#
# ### Riaggiorna i permessi per permettere il push
# chmod 700 ~/.ssh
# chmod 600 ~/.ssh/id_ed25519
#
# ### commit e push
# cd ~/tesi_graphrag
# git add .
# #git commit -m "Autosave rapido da notebook"
# #git commit -m "CUSTOM MSG"
# git commit -m "Aggiornato graph_builder per gestire direttamente i vettori e verificato funzionamento tag postretrieval"
# git push
# Out:
# [addTagReranking d2c342c] Aggiornato graph_builder per gestire direttamente i vettori e verificato funzionamento tag postretrieval
#  8 files changed, 374 insertions(+), 48 deletions(-)
# s/04_tagReranking/{FrontendBackup.ipynb => 04_01_FrontendBackup.ipynb} (100%)
# agReranking/{04_02T_Test.ipynb => 04_02T_VisualTest.ipynb} (71%)
# gReranking/04_03T_TestWithRetrieval.ipynb
# To github.com:Gorky1724/TesiGraphRAG----JupyterHub-UniNuvola.git
# g -> addTagReranking addTagRerankin
