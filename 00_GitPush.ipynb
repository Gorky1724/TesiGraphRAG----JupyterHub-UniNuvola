# %%
# %%bash
#
# ### Riaggiorna i permessi per permettere il push
# chmod 700 ~/.ssh
# chmod 600 ~/.ssh/id_ed25519
#
# ### commit e push
# cd ~/tesi_graphrag
# git add .
# #git commit -m "Autosave rapido da notebook"
# #git commit -m "CUSTOM MSG"
# git commit -m "Nuova istanza dei lavori su distanceReranking iniziata"
# git push
# Out:
# [distanceReranking 67f3a16] Ultimo prima del rollback
# tions(-)s changed, 752 insertions(+), 162 dele
#  create mode 100644 notebooks/04_distanceReranking/04_02T_ToyTest.ipynb
# 4_distanceReranking/{04_02T_TestPipeline.ipynb => 04_99T_ChaoticTestPipeline.ipynb} (72%)
# To github.com:Gorky1724/TesiGraphRAG----JupyterHub-UniNuvola.git
# ing -> distanceRerankingtanceRerank
