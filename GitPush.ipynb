# %%
# %%bash
#
# ### Riaggiorna i permessi per permettere il push
# chmod 700 ~/.ssh
# chmod 600 ~/.ssh/id_ed25519
#
# ### commit e push
# cd ~/tesi_graphrag
# git add .
# #git commit -m "Autosave rapido da notebook"
# #git commit -m "CUSTOM MSG"
# git commit -m "Funzionamento Architettura Verificato"
# git push
# Out:
# [main 7828044] Funzionamento Architettura Verificato
# ons(-)es changed, 501 insertions(+), 104 deleti
#  create mode 100644 src/config.py
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# KEY FILE!          @NPROTECTED PRIVATE
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# for '/home/jovyan/.ssh/id_ed25519' are too open.
#  accessible by others.ur private key files are NOT
# This private key will be ignored.
# bad permissions/jovyan/.ssh/id_ed25519":
# git@github.com: Permission denied (publickey).
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# nd the repository exists.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cd ~/tesi_graphrag\ngit add .\n#git commit -m "Autosave rapido da notebook"\n#git commit -m "CUSTOM MSG"\ngit commit -m "Funzionamento Architettura Verificato"\ngit push\n')
#
# CalledProcessError: Command 'b'cd ~/tesi_graphrag\ngit add .\n#git commit -m "Autosave rapido da notebook"\n#git commit -m "CUSTOM MSG"\ngit commit -m "Funzionamento Architettura Verificato"\ngit push\n'' returned non-zero exit status 128.
