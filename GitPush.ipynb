# %%
# %%bash
# cd ~/tesi_graphrag
# git add .
# #git commit -m "Autosave rapido da notebook"
# #git commit -m "CUSTOM MSG"
# git commit -m "Funzionamento Architettura Verificato"
# git push
# Out:
# [main fbc6512] Finalizzato inserimento e coordinazione anywidget
# 6 deletions(-)d, 30 insertions(+),
# To github.com:Gorky1724/TesiGraphRAG----JupyterHub-UniNuvola.git
#    e928385..fbc6512  main -> main
