# %%
# %%bash
# cd ~/tesi_graphrag
# git add .
# git commit -m "Autosave rapido da notebook"
# git push
# Out:
# [main e928385] Autosave rapido da notebook
#  1 file changed, 6 insertions(+)
# ush.ipynbode 100644 GitP
# To github.com:Gorky1724/TesiGraphRAG----JupyterHub-UniNuvola.git
#    ffa4b5d..e928385  main -> main
