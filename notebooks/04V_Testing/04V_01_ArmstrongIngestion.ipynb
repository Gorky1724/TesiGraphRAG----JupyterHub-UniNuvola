# %%
### Creazione dataset

armstrong_dataset = [
    # --------------------------------------------------------------------------
    # LOUIS ARMSTRONG (JAZZ - 7 Chunk)
    # --------------------------------------------------------------------------
    {
        "id": "louis_armstrong_1",
        "text": "Louis Armstrong è stato uno dei più celebri musicisti jazz del XX secolo. Famoso per la sua voce raschiata e le sue abilità straordinarie alla tromba, ha inciso brani immortali come What a Wonderful World e Hello, Dolly!.",
        "true_domain": "Jazz"
    },
    {
        "id": "louis_armstrong_2",
        "text": "Nella storia della musica jazz, Louis Armstrong, soprannominato Satchmo, ha rivoluzionato l'improvvisazione musicale e l'uso del canto scat, influenzando generazioni di trombettisti e cantanti in tutto il mondo.",
        "true_domain": "Jazz"
    },
    {
        "id": "louis_armstrong_3",
        "text": "Nato a New Orleans, patria del jazz tradizionale, Louis Armstrong si esibì con le celebri formazioni Hot Five e Hot Seven, diventando un'icona globale dell'improvvisazione e dello swing.",
        "true_domain": "Jazz"
    },
    {
        "id": "louis_armstrong_4",
        "text": "Negli anni '30 e '40, Louis Armstrong partecipò a numerosi film di Hollywood e tour internazionali, portando il genere jazz americano nei teatri di tutto il mondo come ambasciatore culturale.",
        "true_domain": "Jazz"
    },
    {
        "id": "louis_armstrong_5",
        "text": "La tecnica alla tromba di Louis Armstrong era caratterizzata da estensione acuta, grande potenza espressiva e senso del ritmo impeccabile, stabilendo gli standard per l'assolo nella musica jazz.",
        "true_domain": "Jazz"
    },
    {
        "id": "louis_armstrong_6",
        "text": "Oltre ai successi discografici, Louis Armstrong pubblicò due autobiografie e fu riconosciuto come una figura chiave nel superamento delle barriere razziali nello spettacolo americano.",
        "true_domain": "Jazz"
    },
    {
        "id": "louis_armstrong_7",
        "text": "Tra i suoi premi e riconoscimenti postumi figura il Grammy Lifetime Achievement Award, a testimonianza del suo impatto indelebile sulla storia della musica del Novecento.",
        "true_domain": "Jazz"
    },

    # --------------------------------------------------------------------------
    # LANCE ARMSTRONG (CICLISMO - 7 Chunk)
    # --------------------------------------------------------------------------
    {
        "id": "lance_armstrong_1",
        "text": "Lance Armstrong è un ex ciclista su strada statunitense, noto per aver vinto il Tour de France per sette volte consecutive dal 1999 al 2005, titoli successivamente revocati a causa del doping.",
        "true_domain": "Ciclismo"
    },
    {
        "id": "lance_armstrong_2",
        "text": "Nel mondo del ciclismo professionistico, Lance Armstrong è ricordato sia per i suoi successi nelle corse a tappe sulle Alpi e sui Pirenei, sia per la sua battaglia contro il cancro e la fondazione della celebre associazione Livestrong.",
        "true_domain": "Ciclismo"
    },
    {
        "id": "lance_armstrong_3",
        "text": "Le tappe montane del Tour de France e le prove a cronometro videro Lance Armstrong dominare la scena ciclistica internazionale per quasi un decennio prima dello scandalo sportivo.",
        "true_domain": "Ciclismo"
    },
    {
        "id": "lance_armstrong_4",
        "text": "Dopo il ritiro temporaneo nel 2005, Lance Armstrong tornò alle gare ciclistiche nel 2009 con la squadra Astana, piazzandosi terzo al Tour de France prima della confessione pubblica sul doping nel 2013.",
        "true_domain": "Ciclismo"
    },
    {
        "id": "lance_armstrong_5",
        "text": "La carriera giovanile di Lance Armstrong iniziò nel triathlon prima di passare al ciclismo su strada con la vittoria del Campionato del Mondo professionisti a Oslo nel 1993.",
        "true_domain": "Ciclismo"
    },
    {
        "id": "lance_armstrong_6",
        "text": "Il team US Postal Service, guidato dal direttore sportivo Johan Bruyneel, ruotava interamente attorno alla preparazione atletica di Lance Armstrong per le tre settimane del Tour de France.",
        "true_domain": "Ciclismo"
    },
    {
        "id": "lance_armstrong_7",
        "text": "A seguito dell'indagine dell'USADA (United States Anti-Doping Agency), tutti i risultati sportivi ottenuti da Lance Armstrong dal 1998 in poi furono cancellati dagli albi d'oro del ciclismo.",
        "true_domain": "Ciclismo"
    },

    # --------------------------------------------------------------------------
    # NEIL ARMSTRONG (ASTRONAUTICA - 7 Chunk)
    # --------------------------------------------------------------------------
    {
        "id": "neil_armstrong_1",
        "text": "Neil Armstrong è stato un astronauta ed esploratore spaziale statunitense, entrato nella storia per essere stato il primo uomo a camminare sulla Luna il 20 luglio 1969 durante la missione spaziale Apollo 11.",
        "true_domain": "Astronautica"
    },
    {
        "id": "neil_armstrong_2",
        "text": "Comandante della missione Apollo 11 della NASA, Neil Armstrong pronunciò la celebre frase: 'Questo è un piccolo passo per un uomo, un grande balzo per l'umanità' mentre posava il piede sul suolo lunare.",
        "true_domain": "Astronautica"
    },
    {
        "id": "neil_armstrong_3",
        "text": "Prima di diventare astronauta della NASA e guidare il modulo lunare Eagle verso il mare della Tranquillità, Neil Armstrong era stato un aviatore e pilota collaudatore di velivoli sperimentali ad alta quota.",
        "true_domain": "Astronautica"
    },
    {
        "id": "neil_armstrong_4",
        "text": "La prima missione nello spazio di Neil Armstrong fu la Gemini 8 nel 1966, durante la quale effettuò il primo aggancio (docking) con successo tra due veicoli spaziali in orbita terrestre.",
        "true_domain": "Astronautica"
    },
    {
        "id": "neil_armstrong_5",
        "text": "Dopo la storica camminata sulla Luna e il rientro sulla Terra, Neil Armstrong si ritirò dalla NASA per insegnare ingegneria aerospaziale all'Università di Cincinnati e collaborare a commissioni d'inchiesta spaziali.",
        "true_domain": "Astronautica"
    },
    {
        "id": "neil_armstrong_6",
        "text": "Durante la discesa del modulo lunare Eagle su una superficie imprevista e ricca di massi, Neil Armstrong prese il controllo manuale guidando il veicolo a un allunaggio sicuro con pochissimo carburante residuo.",
        "true_domain": "Astronautica"
    },
    {
        "id": "neil_armstrong_7",
        "text": "Riconosciuto come un eroe nazionale schivo e riservato, Neil Armstrong fu insignito della Presidential Medal of Freedom e della Congressional Space Medal of Honor per i suoi meriti nell'esplorazione dello spazio.",
        "true_domain": "Astronautica"
    }
]

# %%
import os
import sys
import json
import time
import uuid
from datetime import datetime
from pathlib import Path

from langchain_core.documents import Document
from langchain_community.embeddings import FastEmbedEmbeddings
from langchain_qdrant import QdrantVectorStore
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams

# 1. Setup percorsi e importazioni configurazione
PROJECT_ROOT = Path("~/tesi_graphrag").expanduser().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import EMBEDDING_MODEL, QDRANT_URL

COLLECTION_NAME = "unilanguage_armstrong"
REGISTRY_PATH = PROJECT_ROOT / "data/collection_registry.json"

documents = [
    Document(
        page_content=item["text"],
        metadata={
            "chunk_id": item["id"],
            "doc_id": item["id"],
            "true_domain": item["true_domain"],
            "chunk_index": idx,
            "user_tags": [],
        }
    )
    for idx, item in enumerate(armstrong_dataset)
]

print(f">> Convertiti {len(documents)} chunk in oggetti Document.")

client = QdrantClient(url=QDRANT_URL)
embeddings = FastEmbedEmbeddings(model_name=EMBEDDING_MODEL)
vector_dim = len(embeddings.embed_query("test"))

if not client.collection_exists(COLLECTION_NAME):
    client.create_collection(
        collection_name=COLLECTION_NAME,
        vectors_config=VectorParams(size=vector_dim, distance=Distance.COSINE),
    )

vectorstore = QdrantVectorStore(
    client=client,
    collection_name=COLLECTION_NAME,
    embedding=embeddings
)

start_time = time.perf_counter()
batch_ids = [
    str(uuid.uuid5(uuid.NAMESPACE_DNS, doc.metadata["chunk_id"]))
    for doc in documents
]

# Inserimento/Upsert
vectorstore.add_documents(documents=documents, ids=batch_ids)
elapsed_time = time.perf_counter() - start_time

print(f"!>> Completata l'operazione su {len(documents)} chunk nella collezione '{COLLECTION_NAME}' in {elapsed_time:.2f}s.")

# Aggiornamento registro collezioni
registry_data = {}
if REGISTRY_PATH.exists():
    try:
        with open(REGISTRY_PATH, "r", encoding="utf-8") as f:
            registry_data = json.load(f)
    except Exception:
        registry_data = {}

registry_data[COLLECTION_NAME] = {
    "embedding_model": EMBEDDING_MODEL,
    "vector_dimension": vector_dim,
    "distance_metric": "COSINE",
    "total_chunks": len(documents),
    #"hypothetical_tags": CANDIDATE_TAGS,
    "updated_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
}

REGISTRY_PATH.parent.mkdir(parents=True, exist_ok=True)
with open(REGISTRY_PATH, "w", encoding="utf-8") as f:
    json.dump(registry_data, f, indent=2, ensure_ascii=False)

print(f"!>> Registro aggiornato in: {REGISTRY_PATH.resolve()}")
# Out:
# /tmp/ipykernel_485322/1186459446.py:10: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.embeddings import FastEmbedEmbeddings
# >> Convertiti 21 chunk in oggetti Document.
# !>> Completata l'operazione su 21 chunk nella collezione 'unilanguage_armstrong' in 4.66s.
# !>> Registro aggiornato in: /home/jovyan/tesi_graphrag/data/collection_registry.json

# %%
### Query di benchmark
armstrong_queries = [
    # --- QUERY AMBIGUE (Test di disambiguazione / Sovrapposizione semantica) ---
    {
        "id": "Q_AMBIG_01",
        "type": "ambiguous",
        "query": "Chi è Armstrong e quali sono i principali traguardi raggiunti nella sua carriera?",
        "expected_tag": None,  # Query totalmente generica che tocca tutti e 3 i domini
        "description": "Serve a verificare quali chunk il RAG vettoriale puro recupera quando l'intento non è specificato."
    },
    {
        "id": "Q_AMBIG_02",
        "type": "ambiguous",
        "query": "Quali grandi successi o vittorie ha ottenuto Armstrong?",
        "expected_tag": None,
        "description": "Verifica se il motore mischia le vittorie al Tour de France, i brani musicali o lo sbarco sulla Luna."
    },
    {
        "id": "Q_AMBIG_03",
        "type": "ambiguous",
        "query": "Parlami delle attività svolte da Armstrong negli anni '60.",
        "expected_tag": None,
        "description": "Mette a confronto le registrazioni musicali di Louis, le missioni Gemini/Apollo di Neil e la giovinezza di Lance."
    },

    # --- QUERY SPECIFICHE / ORIENTATE A UN DOMINIO (Test di Re-ranking e Filtering) ---
    {
        "id": "Q_SPEC_JAZZ_01",
        "type": "specific",
        "query": "Quali sono i brani musicali più famosi registrati da Armstrong e che strumento suonava?",
        "expected_tag": "Jazz",
        "description": "Deve attivare il tag Jazz ed elevare solo i chunk relativi alla tromba e a 'What a Wonderful World'."
    },
    {
        "id": "Q_SPEC_BIKE_01",
        "type": "specific",
        "query": "Quali sono le controversie sportive legate alle vittorie di Armstrong nel ciclismo?",
        "expected_tag": "Ciclismo",
        "description": "Deve attivare il tag Ciclismo e concentrarsi sui Tour de France e l'inchiesta USADA."
    },
    {
        "id": "Q_SPEC_ASTRO_01",
        "type": "specific",
        "query": "Quale ruolo ha avuto Armstrong nella missione Apollo 11 e quali frasi celebri ha pronunciato?",
        "expected_tag": "Astronautica",
        "description": "Deve attivare il tag Astronautica e promuovere i chunk legati al modulo lunare Eagle e alla NASA."
    }
]

# %%
import json
from pathlib import Path
# Percorso di salvataggio
output_dir = Path("~/tesi_graphrag/data/queries/armstrong").expanduser()
output_dir.mkdir(parents=True, exist_ok=True)
output_path = output_dir / "eval_queries.json"

# Scrittura su file JSON
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(armstrong_queries, f, indent=4, ensure_ascii=False)

print(f"!> Creato con successo il benchmark file: {output_path.resolve()}")
print(f"<< Totale domande salvate: {len(armstrong_queries)}")
# Out:
# !> Creato con successo il benchmark file: /home/jovyan/tesi_graphrag/data/queries/armstrong/eval_queries.json
# << Totale domande salvate: 6
