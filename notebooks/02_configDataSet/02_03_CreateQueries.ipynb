# %%
# Queries del DataSet1 (ds1)
import json
from pathlib import Path

# Definizione delle queries di benchmark
eval_benchmark = [
    # ------------------------------------------------------------------
    # CATEGORIA 1: SINGLE-HOP / RETRIEVAL VETTORIALE (Puntuali)
    # ------------------------------------------------------------------
    {
        "id": "Q_SINGLE_01",
        "category": "single_hop",
        "difficulty": "easy",
        "tags": ["self-rag", "reflection-tokens"],
        "query": "Qual è la funzione dei reflection token nell'architettura Self-RAG?",
    },
    {
        "id": "Q_SINGLE_02",
        "category": "single_hop",
        "difficulty": "medium",
        "tags": ["crag", "thresholds"],
        "query": "Come definisce CRAG la soglia di valutazione della rilevanza dei documenti?",
    },
    {
        "id": "Q_SINGLE_03",
        "category": "single_hop",
        "difficulty": "easy",
        "tags": ["hyde", "embeddings"],
        "query": "Qual è l'idea centrale di HyDE per generare embedding senza la risposta reale?",
    },
    {
        "id": "Q_SINGLE_04",
        "category": "single_hop",
        "difficulty": "medium",
        "tags": ["raptor", "clustering"],
        "query": "In RAPTOR, come viene costruito il clustering ad albero sui chunk?",
    },
    {
        "id": "Q_SINGLE_05",
        "category": "single_hop",
        "difficulty": "easy",
        "tags": ["rag-lewis", "architecture"],
        "query": "Quale architettura usa il RAG originale di Lewis (2020) per encoder e generator?",
    },
    {
        "id": "Q_SINGLE_06",
        "category": "single_hop",
        "difficulty": "medium",
        "tags": ["flare", "active-retrieval"],
        "query": "In che modo FLARE decide quando attivare il retrieval durante la generazione?",
    },
    {
        "id": "Q_SINGLE_07",
        "category": "single_hop",
        "difficulty": "easy",
        "tags": ["rag-vs-finetuning"],
        "query": "Quali sono le differenze chiave tra RAG e Fine-Tuning nello studio del 2024?",
    },
    {
        "id": "Q_SINGLE_08",
        "category": "single_hop",
        "difficulty": "medium",
        "tags": ["kg-prompting"],
        "query": "Cos'è la tecnica di Knowledge Graph Prompting descritta nel paper del 2023?",
    },
    {
        "id": "Q_SINGLE_09",
        "category": "single_hop",
        "difficulty": "easy",
        "tags": ["kg-rag", "retrieval-stages"],
        "query": "Quali sono i tre stadi del ciclo di recupero definiti nella survey KG-RAG?",
    },
    {
        "id": "Q_SINGLE_10",
        "category": "single_hop",
        "difficulty": "medium",
        "tags": ["graphrag", "community-summaries"],
        "query": "Come vengono generati i community summaries in Microsoft GraphRAG?",
    },
    {
        "id": "Q_SINGLE_11",
        "category": "single_hop",
        "difficulty": "medium",
        "tags": ["crag", "web-search"],
        "query": "Cos'è la fase di Web Search Evaluation presentata nel framework CRAG?",
    },
    {
        "id": "Q_SINGLE_12",
        "category": "single_hop",
        "difficulty": "hard",
        "tags": ["self-rag", "critique-tokens"],
        "query": "In Self-RAG, quali sono i quattro tipi distinti di critique tokens usati dall'LLM?",
    },
    {
        "id": "Q_SINGLE_13",
        "category": "single_hop",
        "difficulty": "medium",
        "tags": ["raptor", "p-tree"],
        "query": "Qual è il ruolo delle 'summary nodes' nei livelli superiori del p-tree di RAPTOR?",
    },
    {
        "id": "Q_SINGLE_14",
        "category": "single_hop",
        "difficulty": "medium",
        "tags": ["kg-prompting", "representation"],
        "query": "Come vengono rappresentate le entità e le relazioni nel formato di input di Knowledge Graph Prompting?",
    },
    {
        "id": "Q_SINGLE_15",
        "category": "single_hop",
        "difficulty": "hard",
        "tags": ["flare", "lookahead"],
        "query": "Qual è la funzione della finestra di lookahead nella generazione adattiva di FLARE?",
    },
    # ------------------------------------------------------------------
    # CATEGORIA 2: MULTI-HOP / RELAZIONALI E COMPARATIVE
    # ------------------------------------------------------------------
    {
        "id": "Q_MULTI_01",
        "category": "multi_hop",
        "difficulty": "medium",
        "tags": ["flare", "self-rag", "comparison"],
        "query": "In che modo FLARE e Self-RAG differiscono nel momento di attivazione del retrieval?",
    },
    {
        "id": "Q_MULTI_02",
        "category": "multi_hop",
        "difficulty": "hard",
        "tags": ["raptor", "graphrag", "hierarchy"],
        "query": "Confronta l'uso della gerarchia in RAPTOR con i cluster di comunità di Microsoft GraphRAG.",
    },
    {
        "id": "Q_MULTI_03",
        "category": "multi_hop",
        "difficulty": "medium",
        "tags": ["crag", "hyde", "noise-handling"],
        "query": "Quali approcci tra CRAG e HyDE gestiscono i contesti rumorosi e con quali strategie?",
    },
    {
        "id": "Q_MULTI_04",
        "category": "multi_hop",
        "difficulty": "medium",
        "tags": ["rag-lewis", "evolution"],
        "query": "In che modo i paper 2023-2024 superano il retriever statico di Lewis (2020)?",
    },
    {
        "id": "Q_MULTI_05",
        "category": "multi_hop",
        "difficulty": "hard",
        "tags": ["kg-rag", "hyde", "structured-vs-dense"],
        "query": "Confronta l'uso di basi di conoscenza strutturate (KG-RAG) e basi vettoriali pure (HyDE).",
    },
    {
        "id": "Q_MULTI_06",
        "category": "multi_hop",
        "difficulty": "medium",
        "tags": ["self-rag", "crag", "evaluation"],
        "query": "Quali strategie di valutazione automatica vengono proposte in Self-RAG e CRAG?",
    },
    {
        "id": "Q_MULTI_07",
        "category": "multi_hop",
        "difficulty": "hard",
        "tags": ["fine-tuning", "rag-evolution"],
        "query": "Come si sono evolute le combinazioni tra RAG e Fine-Tuning dal 2020 al 2024?",
    },
    {
        "id": "Q_MULTI_08",
        "category": "multi_hop",
        "difficulty": "medium",
        "tags": ["self-correction", "comparison"],
        "query": "Quali paper in ds1 usano meccanismi di self-correction e come differiscono?",
    },
    {
        "id": "Q_MULTI_09",
        "category": "multi_hop",
        "difficulty": "hard",
        "tags": ["cost", "indexing", "raptor", "graphrag"],
        "query": "Confronta il costo computazionale di indicizzazione tra RAPTOR, GraphRAG e RAG standard.",
    },
    {
        "id": "Q_MULTI_10",
        "category": "multi_hop",
        "difficulty": "medium",
        "tags": ["hyde", "graphrag", "synthetic-context"],
        "query": "Come varia il 'contesto sintetico' tra HyDE (testo ipotetico) e GraphRAG (sommari)?",
    },
    {
        "id": "Q_MULTI_11",
        "category": "multi_hop",
        "difficulty": "hard",
        "tags": ["graphrag", "raptor", "global-context"],
        "query": "In che modo sia GraphRAG che RAPTOR affrontano il problema del recupero a grana grossa (global context)?",
    },
    {
        "id": "Q_MULTI_12",
        "category": "multi_hop",
        "difficulty": "medium",
        "tags": ["crag", "self-rag", "filtering"],
        "query": "Confronta le tecniche di filtraggio del contesto rumoroso tra CRAG e Self-RAG.",
    },
    {
        "id": "Q_MULTI_13",
        "category": "multi_hop",
        "difficulty": "hard",
        "tags": ["kg-prompting", "graphrag", "neighbors"],
        "query": "Quali sono le differenze nella generazione dei vicini nel grafo tra KG-Prompting e GraphRAG?",
    },
    {
        "id": "Q_MULTI_14",
        "category": "multi_hop",
        "difficulty": "medium",
        "tags": ["metrics", "adaptive-rag"],
        "query": "Come differiscono le metriche di accuratezza utilizzate negli articoli su RAG Adattivo rispetto a RAG Stativo?",
    },
    {
        "id": "Q_MULTI_15",
        "category": "multi_hop",
        "difficulty": "hard",
        "tags": ["context-window", "optimization"],
        "query": "Quali soluzioni vengono adottate nei paper di ds1 per limitare la saturazione della finestra di contesto dell'LLM?",
    },
    # ------------------------------------------------------------------
    # CATEGORIA 3: GLOBAL SEARCH / SINTESI E TRENDS
    # ------------------------------------------------------------------
    {
        "id": "Q_GLOBAL_01",
        "category": "global_search",
        "difficulty": "hard",
        "tags": ["vector-failures", "synthesis"],
        "query": "Quali sono i principali pattern di fallimento della ricerca vettoriale identificati nel dataset ds1?",
    },
    {
        "id": "Q_GLOBAL_02",
        "category": "global_search",
        "difficulty": "medium",
        "tags": ["timeline", "rag-history"],
        "query": "Sintetizza l'evoluzione temporale delle architetture RAG dal 2020 al 2024 nel dataset.",
    },
    {
        "id": "Q_GLOBAL_03",
        "category": "global_search",
        "difficulty": "hard",
        "tags": ["kg-impact", "prompt-structure"],
        "query": "In che modo l'uso dei Knowledge Graph modifica la struttura del contesto dato al LLM?",
    },
    {
        "id": "Q_GLOBAL_04",
        "category": "global_search",
        "difficulty": "medium",
        "tags": ["taxonomy", "rag-types"],
        "query": "Quali sono le principali tassonomie di RAG riscontrabili nei 10 paper del dataset?",
    },
    {
        "id": "Q_GLOBAL_05",
        "category": "global_search",
        "difficulty": "hard",
        "tags": ["trade-off", "accuracy-vs-cost"],
        "query": "Come viene affrontato il trade-off tra costo di indicizzazione e accuratezza nei vari framework?",
    },
    {
        "id": "Q_GLOBAL_06",
        "category": "global_search",
        "difficulty": "medium",
        "tags": ["hallucinations", "definition"],
        "query": "Analizza come i diversi autori definiscono e misurano le allucinazioni nei LLM.",
    },
    {
        "id": "Q_GLOBAL_07",
        "category": "global_search",
        "difficulty": "hard",
        "tags": ["semantic-clustering", "methods"],
        "query": "Quali sono i metodi di raggruppamento semantico più usati nel corpus per la sintesi ad alto livello?",
    },
    {
        "id": "Q_GLOBAL_08",
        "category": "global_search",
        "difficulty": "medium",
        "tags": ["decision-guidelines"],
        "query": "Sintetizza le linee guida del dataset su quando scegliere RAG rispetto al Fine-Tuning.",
    },
    {
        "id": "Q_GLOBAL_09",
        "category": "global_search",
        "difficulty": "medium",
        "tags": ["evaluation-metrics"],
        "query": "Quali metriche di valutazione numeriche sono maggiormente ricorrenti nei paper analizzati?",
    },
    {
        "id": "Q_GLOBAL_10",
        "category": "global_search",
        "difficulty": "hard",
        "tags": ["future-work", "kg-llm"],
        "query": "Quali direzioni future sull'integrazione tra LLM e Grafi emergono dall'analisi globale del dataset?",
    },
    {
        "id": "Q_GLOBAL_11",
        "category": "global_search",
        "difficulty": "hard",
        "tags": ["lost-in-the-middle", "long-context"],
        "query": "In che modo la presenza di grafi di conoscenza mitiga il problema della 'lost in the middle' nei documenti lunghi?",
    },
    {
        "id": "Q_GLOBAL_12",
        "category": "global_search",
        "difficulty": "medium",
        "tags": ["reranking", "reflection"],
        "query": "Qual è l'impatto complessivo delle tecniche di ri-ordinamento (re-ranking) e self-reflection nell'accuratezza finale?",
    },
    {
        "id": "Q_GLOBAL_13",
        "category": "global_search",
        "difficulty": "hard",
        "tags": ["dense-vs-graph"],
        "query": "Sintetizza i ruoli distinti dei retriever densi (dense) vs recupero basato su grafi (graph-based) nel dataset.",
    },
    {
        "id": "Q_GLOBAL_14",
        "category": "global_search",
        "difficulty": "medium",
        "tags": ["kg-construction", "limits"],
        "query": "Quali sono i principali limiti computazionali identificati per la costruzione di Knowledge Graph nell'era dei LLM?",
    },
    {
        "id": "Q_GLOBAL_15",
        "category": "global_search",
        "difficulty": "hard",
        "tags": ["synergy", "structured-unstructured"],
        "query": "Come si articola la sinergia tra informazioni non strutturate (testo) e strutturate (grafi) nella letteratura di ds1?",
    },
]

# Percorso di salvataggio
output_dir = Path("~/tesi_graphrag/data/queries/ds1").expanduser()
output_dir.mkdir(parents=True, exist_ok=True)
output_path = output_dir / "eval_queries.json"

# Scrittura su file JSON
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(eval_benchmark, f, indent=4, ensure_ascii=False)

print(f"!> Creato con successo il benchmark file: {output_path.resolve()}")
print(f"<< Totale domande salvate: {len(eval_benchmark)}")
# Out:
# !> Creato con successo il benchmark file: /home/jovyan/tesi_graphrag/data/queries/ds1/eval_queries.json
# << Totale domande salvate: 45
